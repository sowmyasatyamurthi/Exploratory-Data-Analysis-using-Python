# %%
import pandas as pd

# %%
df_bookings =pd.read_csv("datasets/fact_bookings.csv")
df_bookings.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts() #to show no.of bookings happened in each platform
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind = "barh")
# Out:
# <Axes: ylabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max(),
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
df_date = pd.read_csv("datasets/dim_date.csv")
df_hotels=pd.read_csv("datasets/dim_hotels.csv")
df_rooms = pd.read_csv("datasets/dim_rooms.csv")
df_agg_bookings =pd.read_csv("datasets/fact_aggregated_bookings.csv")

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='city'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
#code to cehck any negative values

df_bookings[df_bookings.no_guests <= 0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
#since there are 134590 rows,we can remove the negative records.
df_bookings = df_bookings[df_bookings.no_guests>0]
df_bookings.shape
# Out:
# (134578, 12)

# %%
#checking code for revenue generated column.a single booking cannot have amount 28560000.
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
#apply standard deviation to identify the outliers
avg, std = df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
avg, std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit = avg + 3* std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limit = avg - 3 *std
lower_limit
# Out:
# np.float64(-263742.4278567056)

# %%
##generatlly revenue generated should not be negative. so ignore lowerlimits. Check on higher limits.

# %%
df_bookings[df_bookings.revenue_generated>higher_limit] ##outliers are greated than higher limit
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
#so above records are erroneous ones.

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings ## storing clean records by removing error rows
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
##verify revenue realised column
df_bookings.describe() # or  df_bookings.revenue_realized.describe()  both are same
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134573.000000  134573.000000   56676.000000      134573.000000
# mean    18061.191658       2.036716       3.619045       14915.959776
# std      1093.042273       1.031673       1.234983        6452.676164
# min     16558.000000       1.000000       1.000000        6500.000000
# 25%     17558.000000       1.000000       3.000000        9900.000000
# 50%     17564.000000       2.000000       4.000000       13500.000000
# 75%     18563.000000       2.000000       5.000000       18000.000000
# max     19563.000000       6.000000       5.000000       45220.000000
#
#        revenue_realized
# count     134573.000000
# mean       12695.983585
# std         6927.791692
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
higher_limit = df_bookings.revenue_realized.mean() + 3 *df_bookings.revenue_realized.std() 
higher_limit
# Out:
# np.float64(33479.358661845814)

# %%
#cehck records
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_rooms#check RT4 type as revenue amount is heavy.presidential rooms are expensive.
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings[df_bookings.room_category == "RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
#calculate mean and 3std  for rt4 alone
23440 + 3* 9048
# Out:
# 50584

# %%
#MAX is less than the above value, so there is no outliners in revenue realised column. So data cleaning is not required.

# %%
##finding NA values
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# PERFORM DATA TRANSFORMATION ie apply calcualtion and formula and save under new column

# %%
df_agg_bookings["occ_pct"]=  df_agg_bookings[ "successful_bookings"] /  df_agg_bookings[ "capacity"] 
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 3  1.578947
# 4  0.947368

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["occ_pct"].apply(lambda x: round(x *100,2))
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %% [markdown]
# what is teh average occupancy rate in each room types.

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %% [markdown]
# now join df_agg_bookings and df_rooms using merge. roomid is common among two dataframes. However the columnlabel is different. Still we can join

# %%
df =pd.merge(df_agg_bookings, df_rooms, left_on = "room_category", right_on ="room_id")
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct room_id    room_class
# ...

# %%
#now get roomwise detail. 
df.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occ_pct, dtype: float64

# %%
df.drop("room_id" , axis =1 ,inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.drop("room_id" , axis =1 ,inplace = True)
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %% [markdown]
# Print average occupancy rate per city

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df =pd.merge(df,df_hotels, on ="property_id")
df.head()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# ...

# %%
df.groupby("city")["occ_pct"].mean().round(2).plot(kind = "bar")
# Out:
# <Axes: xlabel='city'>

# %%
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class property_name_x category_x     city_x property_name_y  \
# 0    83.33   Standard   Atliq Exotica     Luxury     Mumbai   Atliq Exotica
# 1    93.33   Standard       Atliq Bay     Luxury  Bangalore       Atliq Bay
# 2    76.67   Standard    Atliq Palace   Business  Bangalore    Atliq Palace
# 3   157.89   Standard    Atliq Grands     Luxury     Mumbai    Atliq Grands
# 4    94.74   Standard    Atliq Grands     Luxury      Delhi    Atliq Grands
#
#   category_y     city_y  property_name  category       city
# ...

# %% [markdown]
# When was the occupancy weekday or weekend

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df =pd.merge(df,df_date, left_on= 'check_in_date', right_on= 'date')
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct room_class property_name_x category_x     city_x property_name_y  \
# 0    51.72    Premium    Atliq Palace   Business  Bangalore    Atliq Palace
# 1    63.33   Standard      Atliq City   Business  Hyderabad      Atliq City
# 2    60.00   Standard       Atliq Bay     Luxury  Bangalore       Atliq Bay
#
#   category_y     city_y property_name  category       city       date  mmm yy  \
# 0   Business  Bangalore  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 1   Business  Hyderabad    Atliq City  Business  Hyderabad  10-May-22  May 22
# 2     Luxury  Bangalore     Atliq Bay    Luxury  Bangalore  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# ...

# %%
df.groupby("day_type")["occ_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %% [markdown]
# In the month of june what is the occupancy for different cities

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june =df[df["mmm yy"]== 'Jun 22']
df_june.head()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
#
#       occ_pct room_class property_name_x category_x     city_x  \
# 2200    66.67   Standard   Atliq Exotica     Luxury     Mumbai
# 2201    63.33   Standard       Atliq Bay     Luxury  Bangalore
# 2202    56.67   Standard    Atliq Palace   Business  Bangalore
# 2203    47.37   Standard    Atliq Grands     Luxury     Mumbai
# 2204    57.89   Standard    Atliq Grands     Luxury      Delhi
#
#      property_name_y category_y     city_y  property_name  category  \
# ...

# %%
df_june.groupby("city")["occ_pct"].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_pct, dtype: float64

# %% [markdown]
# #A NEW DATA SET IS RECEIVED FOR AUGUST.sO NEED TO APPEND THIS FILE TO CURRENT ONE.

# %%
df_august =pd.read_csv("datasets/new_data_august.csv")
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name_x', 'category_x',
#        'city_x', 'property_name_y', 'category_y', 'city_y', 'property_name',
#        'category', 'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
 df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 20)

# %%
df_latest = pd.concat([df,df_august], ignore_index = True, axis = 0) 
df_latest.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        17558     31-Jul-22           RT4                    3       6.0
# 6498        19563     31-Jul-22           RT4                    3       6.0
# 6499        17561     31-Jul-22           RT4                    3       4.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class property_name_x category_x     city_x  ...  \
# ...

# %%
df_august.shape
# Out:
# (7, 13)

# %% [markdown]
# ##print revenue realised per city

# %%
df_bookings.head()
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_bookings_all = pd.merge(df_bookings, df_hotels, on = "property_id")
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
# ...

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum().round(2)
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %% [markdown]
# #PRING REVENUE MONTH BY MONTH

# %%
pd.merge(df_bookings_all,df_date, left_on = "check_in_date",right_on ="date")
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
##no rows returned, so check teh data type of teh "check_in_date" "mmm yy"

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date["date"] =pd.to_datetime(df['date'])
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB
# C:\Users\nagar\AppData\Local\Temp\ipykernel_15904\8488563.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date["date"] =pd.to_datetime(df['date'])

# %%
df_bookings_all["check_in_date"] =pd.to_datetime(df['check_in_date'])
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      6500 non-null    datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_bookings_all = pd.merge(df_bookings_all,df_date, left_on = "check_in_date",right_on ="date")
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-10      2/5/2022
# 1  May012216558RT12        16558     30-04-22    2022-05-10      2/5/2022
# 2  May012216558RT12        16558     30-04-22    2022-05-10      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1           others            NaN      Cancelled
#
#    ...  category   city     date_x mmm yy_x week no_x day_type_x     date_y  \
# 0  ...    Luxury  Delhi 2022-05-10   May 22      W 19    weekend 2022-05-10
# 1  ...    Luxury  Delhi 2022-05-10   May 22      W 19    weekend 2022-05-10
# 2  ...    Luxury  Delhi 2022-05-10   May 22      W 19    weekend 2022-05-10
#
#   mmm yy_y week no_y day_type_y
# ...

# %%
df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...

# %% [markdown]
# #print revenue realised per hotel type

# %%
df_bookings_all.columns.unique
# Out:
# <bound method Index.unique of Index(['booking_id', 'property_id', 'booking_date', 'check_in_date',
#        'checkout_date', 'no_guests', 'room_category', 'booking_platform',
#        'ratings_given', 'booking_status', 'revenue_generated',
#        'revenue_realized', 'property_name', 'category', 'city', 'date_x',
#        'mmm yy_x', 'week no_x', 'day_type_x', 'date_y', 'mmm yy_y',
#        'week no_y', 'day_type_y'],
#       dtype='object')>

# %%
df_hotels.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city'], dtype='object')

# %%
df_bookings_all.groupby("property_name")["revenue_realized"].sum().round(2).sort_values(ascending =False)
# Out:
# property_name
# Atliq Exotica    320258588
# Atliq Palace     304081863
# Atliq City       285798439
# Atliq Blu        260851922
# Atliq Bay        259996918
# Atliq Grands     211462134
# Atliq Seasons     66086735
# Name: revenue_realized, dtype: int64

# %% [markdown]
# #print month by month revenue

# %%
df_bookings_all.groupby("city")["ratings_given"].sum().round(2)
# Out:
# city
# Bangalore    45697.0
# Delhi        38666.0
# Hyderabad    53799.0
# Mumbai       66951.0
# Name: ratings_given, dtype: float64

# %%
df_bookings_all.groupby("booking_platform")["ratings_given"].sum().round(2).plot(kind = "pie")
# Out:
# <Axes: ylabel='ratings_given'>
